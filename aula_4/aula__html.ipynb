# %% [markdown]
# <a href="https://colab.research.google.com/github/luisfilipe10/data_analysis/blob/main/aula_4/aula__html.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
dados= pd.read_html('/content/100_filmes.html')
dados
# Out:
# [       0                      1
#  0   1998             100 Movies
#  1   1999              100 Stars
#  2   2000             100 Laughs
#  3   2001            100 Thrills
#  4   2002           100 Passions
#  5   2003  100 Heroes & Villains
#  6   2004              100 Songs
#  7   2005       100 Movie Quotes
#  8   2005              25 Scores
#  9   2006             100 Cheers
#  10  2006            25 Musicals
#  11  2007   100 Movies (Updated)
#  12  2008        AFI's 10 Top 10
#  13   vte                    vte,
#                        Film  Release year              Director  \
#  0             Citizen Kane          1941          Orson Welles
#  1               Casablanca          1942        Michael Curtiz
#  2            The Godfather          1972  Francis Ford Coppola
#  3       Gone with the Wind          1939        Victor Fleming
#  4       Lawrence of Arabia          1962            David Lean
#  ..                     ...           ...                   ...
# ...

# %%
type(dados)
# Out:
# list

# %%
len(dados)
# Out:
# 2

# %%
top_filmes = dados[1]

# %%
top_filmes.head(10)
# Out:
#                   Film  Release year                   Director  \
# 0         Citizen Kane          1941               Orson Welles
# 1           Casablanca          1942             Michael Curtiz
# 2        The Godfather          1972       Francis Ford Coppola
# 3   Gone with the Wind          1939             Victor Fleming
# 4   Lawrence of Arabia          1962                 David Lean
# 5     The Wizard of Oz          1939             Victor Fleming
# 6         The Graduate          1967               Mike Nichols
# 7    On the Waterfront          1954                 Elia Kazan
# 8     Schindler's List          1993           Steven Spielberg
# 9  Singin' in the Rain          1952  Gene Kelly, Stanley Donen
#
#                      Production companies 1998 Rank 2007 Rank
# 0                      RKO Radio Pictures         1         1
# 1                   Warner Bros. Pictures         2         3
# 2  Paramount Pictures, Alfran Productions         3         2
# ...
